# %% [markdown]
# <div><img src="pageDeGarde.png"height="300" width="900" ></div>

# %% [markdown]
# <div style="font-size: 30px;font-family: Times New Roman;color: #e12eb0"><em><strong>Introduction Générale</strong></em></div>

# %% [markdown]
# <p style="font-size: 18px;font-family: Times New Roman">En statistiques, en économétrie et en apprentissage automatique, un modèle de régression linéaire est un modèle de régression qui cherche à établir une relation linéaire entre une variable, dite expliquée, et une ou plusieurs variables, dites explicatives. </p>

# %% [markdown]
# <p style="font-size: 18px;font-family: Times New Roman">On parle aussi de modèle linéaire ou de modèle de régression linéaire. </p>

# %% [markdown]
# <p style="font-size: 18px;font-family: Times New Roman">Régression linéaire des moindres carrés ordinaires.</p>
#
# <p style="font-size: 18px;font-family: Times New Roman">Régression linéaire ajuste un modèle linéaire avec des coefficients w = (w1,…, wp) pour minimiser la somme résiduelle des carrés entre les cibles observées dans le jeu de données et les cibles prédites par l'approximation linéaire.</p>

# %% [markdown]
# <div style="font-size: 30px;font-family: Times New Roman;color: #2f8ede"><em><strong>Partie Pratique</strong></em></div>

# %% [markdown]
# <div style="font-size: 23px;font-family: Times New Roman;color: #e6005c"><strong>Exemple 1</strong></div>

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">1) Importation des package et de dataset</div>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
souidene_ons = pd.read_csv('grav.csv')
#affichage la taille du dataset (n_lignes et n_colonnes)
print("grav's shape:",souidene_ons.shape)
# Out:
# grav's shape: (7, 2)

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">2) Affichage les lignes du dataset</div>

# %%
souidene_ons.head()
# Out:
#    height  seconds squared
# 0     100            8.967
# 1     120           11.989
# 2     150           15.852
# 3     180           16.991
# 4     200           20.284

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">3) Affichage le nuage des points</div>

# %%
x= souidene_ons['height']
y= souidene_ons ['seconds squared']
plt.xlabel('height')
plt.ylabel('seconds squared')
plt.scatter(x,y)

# %% [markdown]
# <strong><center>Fig1: Nuage des points</center></strong>

# %% [markdown]
# <div style="font-size: 18px;font-family: Times New Roman"> <center> ==> Puisque on a travailler sur une seule input et un seul output donc notre résultat est une <strong><em> droite</em> </strong></center></div>

# %% [markdown]
# <div style="font-size: 22px;font-family: Times New Roman;color: #5b84c7"><strong>Note : </strong></div>

# %% [markdown]
# <div style="font-size: 18px;font-family: Times New Roman">En géométrie, la droite désigne un objet géométrique formé de points alignés. Elle est illimitée des deux côtés, et sans épaisseur. </div>

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">4) Corrélation :</div>

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.99473243],
#        [0.99473243, 1.        ]])

# %% [markdown]
# <div style="font-size: 22px;font-family: Times New Roman;color: #5b84c7"><strong>Note : </strong></div>

# %% [markdown]
# <div style="font-size: 18px;font-family: Times New Roman"> la corrélation entre plusieurs variables aléatoires ou statistiques est une notion de liaison qui contredit leur indépendance </div>

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">5)Calculez une régression linéaire des moindres carrés pour deux ensembles de mesures : </div>

# %%
from scipy import stats
stats.linregress(x,y)
# Out:
# LinregressResult(slope=0.10280912511759172, intercept=-0.6801232361241745, rvalue=0.9947324344135698, pvalue=3.857021649169523e-06, stderr=0.004737919558962453)

# %% [markdown]
# <div style="font-size: 23px;font-family: Times New Roman;color: #e6005c"><strong>Exemple 2</strong></div>

# %% [markdown]
# <div style="font-size: 18px;font-family: Times New Roman"> Dans cette pertie on va basé sur 2 variables en input donc parle içi d'<strong>Hyperplan</strong> </div>

# %% [markdown]
# <div style="font-size: 22px;font-family: Times New Roman;color: #5b84c7"><strong>Note : </strong></div>

# %% [markdown]
# <div style="font-size: 18px;font-family: Times New Roman"> les hyperplans d'un espace vectoriel E de dimension quelconque sont la généralisation des plans vectoriels d'un espace de dimension 3 : ce sont les sous-espaces vectoriels de codimension 1 dans E. Si E est de dimension finie n, ses hyperplans sont donc ses sous-espaces de dimension n – 1 : par exemple l'espace nul dans une droite vectorielle, une droite vectorielle dans un plan vectoriel, etc</div>

# %%
df = pd.read_csv('test_scores.csv')
#affichage des 5 premiers lignes
df.head()
# Out:
#   school  school_setting  school_type classroom  teaching_method  n_student  \
# 0  ANKYI             1.0          2.0       6OL              0.0       20.0
# 1  ANKYI             1.0          2.0       6OL              0.0       20.0
# 2  ANKYI             1.0          2.0       6OL              0.0       20.0
# 3  ANKYI             1.0          2.0       6OL              0.0       20.0
# 4  ANKYI             1.0          2.0       6OL              0.0       20.0
#
#   student_id  gender  lunch  pretest  posttest
# 0      2FHT3     1.0    2.0     62.0      72.0
# 1      3JIVH     1.0    2.0     66.0      79.0
# 2      3XOWE     0.0    2.0     64.0      76.0
# 3      556O0     1.0    2.0     61.0      77.0
# 4      74LOE     0.0    2.0     64.0      76.0

# %% [markdown]
# <strong><center>Fig2: test_score.csv</center></strong>

# %%
from ipywidgets import interact
import ipywidgets as widgets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import scipy as sci

def onClick(buttons):
    control = buttons
    
     ##############################Button1######################################
    if control == 'n_student + pretest': 
        X = df[['n_student', 'pretest']].values.reshape(-1,2)
        Y = df['posttest']

######################## Prepare model data point for visualization ###############################

        x = X[:, 0]
        y = X[:, 1]
        z = Y

        x_pred = np.linspace(6, 24, 30)   # range of porosity values
        y_pred = np.linspace(0, 100, 30)  # range of brittleness values
        xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
        model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

################################################ Train #############################################

        result = linear_model.LinearRegression()
        model = result.fit(X, Y)
        predicted = model.predict(model_viz)

############################################## Evaluate ############################################

        r2 = model.score(X, Y)

############################################## Plot ################################################

        plt.style.use('default')

        fig = plt.figure(figsize=(12, 4))

        ax1 = fig.add_subplot(131, projection='3d')
        ax2 = fig.add_subplot(132, projection='3d')
        ax3 = fig.add_subplot(133, projection='3d')

        axes = [ax1, ax2, ax3]

        for ax in axes:
            ax.plot(x, y, z, color='#ea88e7', zorder=15, linestyle='none', marker='o', alpha=0.5)
            ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
            ax.set_xlabel('n_student', fontsize=12)
            ax.set_ylabel('pretest', fontsize=12)
            ax.set_zlabel('posttest', fontsize=12)
            ax.locator_params(nbins=4, axis='x')
            ax.locator_params(nbins=5, axis='x')


        ax1.view_init(elev=28, azim=120)
        ax2.view_init(elev=4, azim=114)
        ax3.view_init(elev=60, azim=165)

        fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

        fig.tight_layout()
        
        X = array(df['n_student'])
        Y=  array(df['pretest'])
        Z = array(df['posttest'])
        print('Corrélation')
        print(corrcoef([X,Y,Z]))
        X = df[['n_student', 'pretest']]
        Y = df['posttest']
        regr = linear_model.LinearRegression()
        regr.fit(X, Y)
        print('.......................................')
        print('Intercept: \n', regr.intercept_)
        print('Coefficients: \n', regr.coef_)
        
    ##############################Button2######################################
    elif control == 'school_setting + pretest': 
        X = df[['school_setting', 'pretest']].values.reshape(-1,2)
        Y = df['posttest']

######################## Prepare model data point for visualization ###############################

        x = X[:, 0]
        y = X[:, 1]
        z = Y

        x_pred = np.linspace(6, 24, 30)   # range of porosity values
        y_pred = np.linspace(0, 100, 30)  # range of brittleness values
        xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
        model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

################################################ Train #############################################

        result = linear_model.LinearRegression()
        model = result.fit(X, Y)
        predicted = model.predict(model_viz)

############################################## Evaluate ############################################

        r2 = model.score(X, Y)

############################################## Plot ################################################

        plt.style.use('default')

        fig = plt.figure(figsize=(12, 4))

        ax1 = fig.add_subplot(131, projection='3d')
        ax2 = fig.add_subplot(132, projection='3d')
        ax3 = fig.add_subplot(133, projection='3d')

        axes = [ax1, ax2, ax3]

        for ax in axes:
            ax.plot(x, y, z, color='#ea88e7', zorder=15, linestyle='none', marker='o', alpha=0.5)
            ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
            ax.set_xlabel('school_setting', fontsize=12)
            ax.set_ylabel('pretest', fontsize=12)
            ax.set_zlabel('posttest', fontsize=12)
            ax.locator_params(nbins=4, axis='x')
            ax.locator_params(nbins=5, axis='x')


        ax1.view_init(elev=28, azim=120)
        ax2.view_init(elev=4, azim=114)
        ax3.view_init(elev=60, azim=165)

        fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)
        print('Corrélation')
        fig.tight_layout()
        X = array(df['school_setting'])
        Y=  array(df['pretest'])
        Z = array(df['posttest'])

        print(corrcoef([X,Y,Z]))
        X = df[['school_setting', 'pretest']]
        Y = df['posttest']
        regr = linear_model.LinearRegression()
        regr.fit(X, Y)
        print('.......................................')
        print('Intercept: \n', regr.intercept_)
        print('Coefficients: \n', regr.coef_)
        
        
        
##############################Button3#########################
    elif control == 'school_type + pretest': 
        X = df[['school_type', 'pretest']].values.reshape(-1,2)
        Y = df['posttest']

######################## Prepare model data point for visualization ###############################

        x = X[:, 0]
        y = X[:, 1]
        z = Y

        x_pred = np.linspace(6, 24, 30)   # range of porosity values
        y_pred = np.linspace(0, 100, 30)  # range of brittleness values
        xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
        model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

################################################ Train #############################################

        result = linear_model.LinearRegression()
        model = result.fit(X, Y)
        predicted = model.predict(model_viz)

############################################## Evaluate ############################################

        r2 = model.score(X, Y)

############################################## Plot ################################################

        plt.style.use('default')

        fig = plt.figure(figsize=(12, 4))

        ax1 = fig.add_subplot(131, projection='3d')
        ax2 = fig.add_subplot(132, projection='3d')
        ax3 = fig.add_subplot(133, projection='3d')

        axes = [ax1, ax2, ax3]

        for ax in axes:
            ax.plot(x, y, z, color='#ea88e7', zorder=15, linestyle='none', marker='o', alpha=0.5)
            ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
            ax.set_xlabel('school_type', fontsize=12)
            ax.set_ylabel('pretest', fontsize=12)
            ax.set_zlabel('posttest', fontsize=12)
            ax.locator_params(nbins=4, axis='x')
            ax.locator_params(nbins=5, axis='x')


        ax1.view_init(elev=28, azim=120)
        ax2.view_init(elev=4, azim=114)
        ax3.view_init(elev=60, azim=165)

        fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

        fig.tight_layout()
        print('Corrélation')
        X = array(df['school_type'])
        Y=  array(df['pretest'])
        Z = array(df['posttest'])

        print(corrcoef([X,Y,Z]))
        print('.......................................')
        X = df[['school_type', 'pretest']]
        Y = df['posttest']
        regr = linear_model.LinearRegression()
        regr.fit(X, Y)

        print('Intercept: \n', regr.intercept_)
        print('Coefficients: \n', regr.coef_)

     ###################################Button4###################################   
    elif control == 'teaching_method + pretest': 
        X = df[['teaching_method', 'pretest']].values.reshape(-1,2)
        Y = df['posttest']

######################## Prepare model data point for visualization ###############################

        x = X[:, 0]
        y = X[:, 1]
        z = Y

        x_pred = np.linspace(6, 24, 30)   # range of porosity values
        y_pred = np.linspace(0, 100, 30)  # range of brittleness values
        xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
        model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

################################################ Train #############################################

        result = linear_model.LinearRegression()
        model = result.fit(X, Y)
        predicted = model.predict(model_viz)

############################################## Evaluate ############################################

        r2 = model.score(X, Y)

############################################## Plot ################################################

        plt.style.use('default')

        fig = plt.figure(figsize=(12, 4))

        ax1 = fig.add_subplot(131, projection='3d')
        ax2 = fig.add_subplot(132, projection='3d')
        ax3 = fig.add_subplot(133, projection='3d')

        axes = [ax1, ax2, ax3]

        for ax in axes:
            ax.plot(x, y, z, color='#ea88e7', zorder=15, linestyle='none', marker='o', alpha=0.5)
            ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
            ax.set_xlabel('teaching_method', fontsize=12)
            ax.set_ylabel('pretest', fontsize=12)
            ax.set_zlabel('posttest', fontsize=12)
            ax.locator_params(nbins=4, axis='x')
            ax.locator_params(nbins=5, axis='x')


        ax1.view_init(elev=28, azim=120)
        ax2.view_init(elev=4, azim=114)
        ax3.view_init(elev=60, azim=165)

        fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

        fig.tight_layout() 
        print('Corrélation')
        X = array(df['teaching_method'])
        Y=  array(df['pretest'])
        Z = array(df['posttest'])

        print(corrcoef([X,Y,Z]))
        print('.......................................')
        X = df[['teaching_method', 'pretest']]
        Y = df['posttest']
        regr = linear_model.LinearRegression()
        regr.fit(X, Y)

        print('Intercept: \n', regr.intercept_)
        print('Coefficients: \n', regr.coef_)
        
#########################Button5##################################
    elif control == 'gender + pretest': 
        X = df[['gender', 'pretest']].values.reshape(-1,2)
        Y = df['posttest']

######################## Prepare model data point for visualization ###############################

        x = X[:, 0]
        y = X[:, 1]
        z = Y

        x_pred = np.linspace(6, 24, 30)   # range of porosity values
        y_pred = np.linspace(0, 100, 30)  # range of brittleness values
        xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
        model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

################################################ Train #############################################

        result = linear_model.LinearRegression()
        model = result.fit(X, Y)
        predicted = model.predict(model_viz)

############################################## Evaluate ############################################

        r2 = model.score(X, Y)

############################################## Plot ################################################

        plt.style.use('default')

        fig = plt.figure(figsize=(12, 4))

        ax1 = fig.add_subplot(131, projection='3d')
        ax2 = fig.add_subplot(132, projection='3d')
        ax3 = fig.add_subplot(133, projection='3d')

        axes = [ax1, ax2, ax3]

        for ax in axes:
            ax.plot(x, y, z, color='#ea88e7', zorder=15, linestyle='none', marker='o', alpha=0.5)
            ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
            ax.set_xlabel('gender', fontsize=12)
            ax.set_ylabel('pretest', fontsize=12)
            ax.set_zlabel('posttest', fontsize=12)
            ax.locator_params(nbins=4, axis='x')
            ax.locator_params(nbins=5, axis='x')


        ax1.view_init(elev=28, azim=120)
        ax2.view_init(elev=4, azim=114)
        ax3.view_init(elev=60, azim=165)

        fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

        fig.tight_layout()
        print('Corrélation')
        X = array(df['gender'])
        Y=  array(df['pretest'])
        Z = array(df['posttest'])

        print(corrcoef([X,Y,Z]))
        print('.......................................')
        X = df[['gender', 'pretest']]
        Y = df['posttest']
        regr = linear_model.LinearRegression()
        regr.fit(X, Y)

        print('Intercept: \n', regr.intercept_)
        print('Coefficients: \n', regr.coef_)
        
############################"Button6#####################
    elif control == 'lunch + pretest': 
        X = df[['lunch', 'pretest']].values.reshape(-1,2)
        Y = df['posttest']

######################## Prepare model data point for visualization ###############################

        x = X[:, 0]
        y = X[:, 1]
        z = Y

        x_pred = np.linspace(6, 24, 30)   # range of porosity values
        y_pred = np.linspace(0, 100, 30)  # range of brittleness values
        xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
        model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

################################################ Train #############################################

        result = linear_model.LinearRegression()
        model = result.fit(X, Y)
        predicted = model.predict(model_viz)

############################################## Evaluate ############################################

        r2 = model.score(X, Y)

############################################## Plot ################################################

        plt.style.use('default')

        fig = plt.figure(figsize=(12, 4))

        ax1 = fig.add_subplot(131, projection='3d')
        ax2 = fig.add_subplot(132, projection='3d')
        ax3 = fig.add_subplot(133, projection='3d')

        axes = [ax1, ax2, ax3]

        for ax in axes:
            ax.plot(x, y, z, color='#ea88e7', zorder=15, linestyle='none', marker='o', alpha=0.5)
            ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
            ax.set_xlabel('lunch', fontsize=12)
            ax.set_ylabel('pretest', fontsize=12)
            ax.set_zlabel('posttest', fontsize=12)
            ax.locator_params(nbins=4, axis='x')
            ax.locator_params(nbins=5, axis='x')


        ax1.view_init(elev=28, azim=120)
        ax2.view_init(elev=4, azim=114)
        ax3.view_init(elev=60, azim=165)

        fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

        fig.tight_layout()
        print('Corrélation')
        X = array(df['lunch'])
        Y=  array(df['pretest'])
        Z = array(df['posttest'])

        print(corrcoef([X,Y,Z]))
        print('.......................................')
        X = df[['lunch', 'pretest']]
        Y = df['posttest']
        regr = linear_model.LinearRegression()
        regr.fit(X, Y)

        print('Intercept: \n', regr.intercept_)
        print('Coefficients: \n', regr.coef_)
        
    return buttons
        
interact(onClick, buttons = widgets.ToggleButtons(
options=['n_student + pretest','school_setting + pretest','school_type + pretest',
         'teaching_method + pretest','gender + pretest','lunch + pretest'],
description='Les inputs sont:',
disabled=False))
# Out:
# interactive(children=(ToggleButtons(description='Les inputs sont:', options=('n_student + pretest', 'school_se…
# <function __main__.onClick(buttons)>

# %% [markdown]
# <strong><center>Fig3: Affichage des hyperplans</center></strong>

# %% [markdown]
# <div style="font-size: 22px;font-family: Times New Roman;color: #5b84c7"><strong>Note : </strong></div>

# %% [markdown]
#  <div style="font-size: 18px;font-family: Times New Roman">Le meilleur qui a en input"pretest et teaching_method" et output"posttest" car il a une R“ meileur que d'autre de l'ordre de 0.95 </div>

# %% [markdown]
# <div style="font-size: 22px;font-family: Times New Roman;color: #5b84c7"><strong>Définition : </strong></div>

# %% [markdown]
#  <div style="font-size: 18px;font-family: Times New Roman">What Is R-Squared?
#
# R-squared (R2) is a statistical measure that represents the proportion of the variance for a dependent variable that's explained by an independent variable or variables in a regression model. Whereas correlation explains the strength of the relationship between an independent and dependent variable, R-squared explains to what extent the variance of one variable explains the variance of the second variable. So, if the R2 of a model is 0.50, then approximately half of the observed variation can be explained by the model's inputs. </div>

# %% [markdown]
# <div style="font-size: 23px;font-family: Times New Roman;color: #e6005c"><strong>Exemple 3</strong></div>

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">*Import the data and specify the variable types with the Type node</div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df1 = pd.read_csv('housing.data.txt')
#affichage des 5 premiers lignes
df1.head()
# Out:
#       CIRM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df1.info()
df1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CIRM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB
#              CIRM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# ...

# %% [markdown]
# <div style="font-size: 22px;font-family: Times New Roman;color: #5b84c7"><strong>Note : </strong></div>

# %% [markdown]
# <div style="font-size: 18px;font-family: Times New Roman">Type Node c'est à dire Integer : donc on a RAD w CHAs</div>
# <div style="font-size: 18px;font-family: Times New Roman"><srong>Node:</strong> Renvoie un entier (integer) qui spécifie le type du noeud ; les valeurs possibles sont listées dans Constantes</div>

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">*Add a Regression node to the stream and select MEDV as the target variable and all other variables as the input</div>

# %%
X = df1[['CIRM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']]
y = df1['MEDV']

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">*Inspect  the  model  nugget  and  identify  the  estimated  coefficients  and  the  regression  equation.  Which  va-riables are included in the final model, and which variable has a coefficient of 3.832?</div>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X , y, test_size=0.4)

lm = LinearRegression()
lm.fit(X_train,y_train)

coefficients = pd.DataFrame(lm.coef_,X.columns)
coefficients.columns = ['coefficients']
coefficients
# Out:
#          coefficients
# CIRM        -0.040920
# ZN           0.018396
# INDUS        0.123782
# CHAS         2.836955
# NOX        -18.484461
# RM           6.060198
# AGE         -0.019522
# DIS         -1.128063
# RAD          0.215059
# TAX         -0.013217
# PTRATIO     -0.915374
# B            0.011625
# LSTAT       -0.311833

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">*What is the value of R2and the adjusted R2</div>

# %%
from sklearn import metrics
train_predictions = lm.predict(X_train)
test_predictions = lm.predict(X_test)

print('MAE for training data:', metrics.mean_absolute_error(y_train, train_predictions))
print('MAE for testing data :', metrics.mean_absolute_error(y_test, test_predictions))
print('.........................................')
print('MSE for training data:', metrics.mean_squared_error(y_train, train_predictions))
print('MSE for testing data :', metrics.mean_squared_error(y_test, test_predictions))
print('.........................................')
print('RMSE for training data:', np.sqrt(metrics.mean_squared_error(y_train, train_predictions)))
print('RMSE for testing data :', np.sqrt(metrics.mean_squared_error(y_test, test_predictions)))
# Out:
# MAE for training data: 3.1719152937922925
# MAE for testing data : 3.397025423341979
# .........................................
# MSE for training data: 20.03338558012731
# MSE for testing data : 30.08414854886267
# .........................................
# RMSE for training data: 4.475867019933379
# RMSE for testing data : 5.484901872309355

# %% [markdown]
# <div style="font-size: 20px;font-family: Times New Roman;color: #e79f82">*Include a Partition node in the stream and divide the dataset into 70 % training data and 30 % test data</div>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 3.4911040247789806
# MSE: 31.965186187414353
# RMSE: 5.653776276738792

# %% [markdown]
# <div style="font-size: 22px;font-family: Times New Roman;color: #2f8ede"><em><strong>Partie II</strong></em></div>

# %% [markdown]
# <div style="font-size: 18px;font-family: Times New Roman">Dependences are fundamental to record the computational enviroment.</div>
# <div style="font-size: 18px;font-family: Times New Roman">Use <strong>watermark</strong> to print version of python ,ipython, and packages,and characteristics of the computar</div>

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.10.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.12
# anaconda-project                   0.8.3
# argh                               0.26.2
# asn1crypto                         1.3.0
# astroid                            2.4.2
# astropy                            4.0.1.post1
# astunparse                         1.6.3
# atomicwrites                       1.4.0
# attrs                              19.3.0
# autopep8                           1.5.3
# Babel                              2.8.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.9.1
# ...

# %%
conda env export > environment.yaml
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div style="font-size: 30px;font-family: Times New Roman;color: #e12eb0"><em><strong>Conclusion Générale</strong></em></div>

# %% [markdown]
# <div style="font-size: 18px;font-family: Times New Roman" >Les modèles de régression linéaire sont relativement simples. Ils génèrent une formule mathématique facile à interpréter qui peut générer des prévisions. Une régression linéaire peut être appliquée à divers domaines d'études commerciales et universitaires.</div>
#
# <div style="font-size: 18px;font-family: Times New Roman" > La régression linéaire est utilisée dans de nombreux domaines tels que les sciences biologiques, comportementales, environnementales et sociales ou dans les entreprises. Les modèles de régression linéaire constituent un moyen éprouvé de prévision scientifique et fiable du futur. La régression linéaire étant une procédure statistique établie de longue date, les propriétés de ses modèles sont bien connues et peuvent donc être enseignées très rapidement.</div>
